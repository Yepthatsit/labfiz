# %%
import pandas as pd
import statsmodels.api as sm
import numpy as np
import matplotlib.pyplot as plt
a = []
data = pd.read_excel('cw45.xlsx')
U = np.arange(150,250,25)
print(U)
R = 20
n = 154
print(data)
# Out:
# [150 175 200 225]
#   Unnamed: 0          150V        150V.1        150V.2        150V.3  \
# 0      r[cm]  2.000000e+00  3.000000e+00  4.000000e+00  5.000000e+00
# 1       I[A]  3.260000e+00  2.130000e+00  1.550000e+00  1.210000e+00
# 2        e/m  1.475932e+11  1.536596e+11  1.632218e+11  1.714158e+11
#
#            175V        175V.1        175V.2        175V.3          200V  \
# 0  2.000000e+00  3.000000e+00  4.000000e+00  5.000000e+00  2.000000e+00
# 1  3.580000e+00  2.330000e+00  1.690000e+00  1.350000e+00  3.760000e+00
# 2  1.427849e+11  1.498145e+11  1.601824e+11  1.606574e+11  1.479328e+11
#
#          200V.1        200V.2        200V.3          225V        225V.1  \
# 0  3.000000e+00  4.000000e+00  5.000000e+00  2.000000e+00  3.000000e+00
# 1  2.430000e+00  1.790000e+00  1.410000e+00  3.930000e+00  2.570000e+00
# 2  1.574147e+11  1.631827e+11  1.683147e+11  1.523378e+11  1.583230e+11
#
#          225V.2        225V.3
# 0  4.000000e+00  5.000000e+00
# ...

# %%
r1 = 2
U2cm = [f"{i}V" for i in U]
X = np.square(list(data.loc[1,U2cm]))
Y = 2.48*10**12*U*R**2/(n**2*r1**2)
plt.scatter(X,Y)
model = sm.OLS(Y,X)
results = model.fit()
print(results.summary())
a.append(results.params[0])
plt.title(f"r = {r1}")
plt.xlabel('X')
plt.ylabel('Y')
plt.plot(X,results.params[0]*X,c = 'r')
plt.show()
# Out:
#                                  OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared (uncentered):                   0.999
# Model:                            OLS   Adj. R-squared (uncentered):              0.999
# Method:                 Least Squares   F-statistic:                              5263.
# Date:                Sat, 15 Jun 2024   Prob (F-statistic):                    5.77e-06
# Time:                        09:49:23   Log-Likelihood:                         -104.00
# No. Observations:                   4   AIC:                                      210.0
# Df Residuals:                       3   BIC:                                      209.4
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
r1 = 3
U2cm = [f"{i}V.1" for i in U]
X = np.square(list(data.loc[1,U2cm]))
Y = 2.48*10**12*U*R**2/(n**2*r1**2)
plt.scatter(X,Y)
model = sm.OLS(Y,X)
results = model.fit()
print(results.summary())
a.append(results.params[0])
plt.xlabel('X')
plt.ylabel('Y')
plt.title(f"r = {r1}")
plt.plot(X,results.params[0]*X,c = 'r')
plt.show()
# Out:
# c:\Users\karol\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\stats\stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
#                                  OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared (uncentered):                   1.000
# Model:                            OLS   Adj. R-squared (uncentered):              0.999
# Method:                 Least Squares   F-statistic:                              6224.
# Date:                Sat, 15 Jun 2024   Prob (F-statistic):                    4.49e-06
# Time:                        09:49:23   Log-Likelihood:                         -100.42
# No. Observations:                   4   AIC:                                      202.8
# Df Residuals:                       3   BIC:                                      202.2
# ...

# %%
r1 = 4
U2cm = [f"{i}V.2" for i in U]
X = np.square(list(data.loc[1,U2cm]))
Y = 2.48*10**12*U*R**2/(n**2*r1**2)
plt.scatter(X,Y)
model = sm.OLS(Y,X)
results = model.fit()
print(results.summary())
a.append(results.params[0])
plt.xlabel('X')
plt.ylabel('Y')
plt.title(f"r = {r1}")
plt.plot(X,results.params[0]*X,c = 'r')
plt.show()
# Out:
#                                  OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared (uncentered):                   1.000
# Model:                            OLS   Adj. R-squared (uncentered):              1.000
# Method:                 Least Squares   F-statistic:                          5.457e+04
# Date:                Sat, 15 Jun 2024   Prob (F-statistic):                    1.73e-07
# Time:                        09:49:23   Log-Likelihood:                         -93.775
# No. Observations:                   4   AIC:                                      189.5
# Df Residuals:                       3   BIC:                                      188.9
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
r1 = 5
U2cm = [f"{i}V.3" for i in U]
X = np.square(list(data.loc[1,U2cm]))
Y = 2.48*10**12*U*R**2/(n**2*r1**2)
plt.scatter(X,Y)
model = sm.OLS(Y,X)
results = model.fit()
print(results.summary())
plt.title(f"r = {r1}")
plt.xlabel('X')
plt.ylabel('Y')
a.append(results.params[0])
plt.plot(X,results.params[0]*X,c = 'r')
plt.show()
# Out:
# c:\Users\karol\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\stats\stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
#                                  OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared (uncentered):                   0.999
# Model:                            OLS   Adj. R-squared (uncentered):              0.999
# Method:                 Least Squares   F-statistic:                              5692.
# Date:                Sat, 15 Jun 2024   Prob (F-statistic):                    5.13e-06
# Time:                        09:49:23   Log-Likelihood:                         -96.509
# No. Observations:                   4   AIC:                                      195.0
# Df Residuals:                       3   BIC:                                      194.4
# ...

# %%
print(f"dane {a} srednia {format(np.mean(a),'e')} odchylenie = {format(np.std(a),'e')}")
print(format(np.mean(a) + np.std(a),'e'))
# Out:
# dane [148165936261.0108, 155379137840.081, 162446106544.33395, 167435302803.4068] srednia 1.583566e+11 odchylenie = 7.277737e+09
# 1.656344e+11
